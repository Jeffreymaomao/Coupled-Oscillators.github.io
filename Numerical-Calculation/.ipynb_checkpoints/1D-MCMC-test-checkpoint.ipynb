# %% [markdown]
# # Errro Testing

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colormaps
from numpy.random import random
from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from lib.Model import *

plt.rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 13,
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsfonts}",
    "lines.linewidth": 1,
    "lines.markersize": 3
})

Model = lambda t, params, m, xi, vi:Analytical_Model(t, k=params, m=m, x1_i=xi[0], x2_i=xi[1], v1_i=vi[0], v2_i=vi[1])

# %% [markdown]
# ## Mean Square Error
# define the mean square error (MSE) to be
# $$
# E_{\rm MSE}\left(\vec{k}\right) = \frac{1}{N}\sum_{i=1}^{2}\sum_{j=0}^{N-1}\left(x_{i,j}-x_{\rm theory,j}\left(\vec{k}\right)\right)^2,
# $$
# where the experimental position data points are given by
# $$
# x_{i,j},\quad j=0,1,\ldots, N-1,
# $$
# where $i=1,2$ denote the two masses position, and $\vec{k}=\left(k_1,k_2,k_3\right)$ denote the spring constant.
#
# Define the probability to be
# $$
# P\left(\vec{k}\right) = \exp\left(-E_{\rm MSE}\left(\vec{k}\right)^2\right)
# $$

# %% [markdown]
# ## First testing
# - fix for $k_1$ and $k_3$ to be $100$
# - using $k_2 = 10$ to be the target spring constant

# %%
t = np.arange(0,5,0.01)
k = (100,100,100)
m = (1.0, 1.0)
xi = (0.0, -0.2)
vi = (0, 0)
(x1_data, x2_data, v1_data, v2_data) = Model(t, k, m, xi, vi)

fig = plt.figure(figsize=(8,2),dpi=100)
plt.plot(t,x1_data, color="red", label=r"$x_1$")
plt.plot(t,x2_data, color="blue", label=r"$x_2$")
plt.legend()
plt.xlabel(r"$t$")
plt.ylabel(r"$x$")
plt.tight_layout()
plt.show()

# %%
fig.savefig("../MCMC-note/fig/exp-data.pdf" , pad_inches=0.1)

# %% [markdown]
# ## Mean Square Error

# %%
def MSE(t, k, x1_data, x2_data, m, xi, vi):
    N = len(t)
    x1_theo, x2_theo, v1_theo ,v2_theo = Model(t, k, m, xi, vi)
    MSE1 = np.sum((x1_data - x1_theo)**2) / N
    MSE2 = np.sum((x2_data - x2_theo)**2) / N
    return MSE1+MSE2

def P_MSE(t, k, x1_data, x2_data, m, xi, vi):
    mse = MSE(t, k, x1_data, x2_data, m, xi, vi)
    P = np.exp(-(MSE1+MSE2))
    return P

def P_MSE(t, k, x1_data, x2_data, m, xi, vi):
    mse = MSE(t, k, x1_data, x2_data, m, xi, vi)
    P = np.exp(-(MSE1+MSE2))
    return np.exp(100*(P-1))

# %%
k2 = np.linspace(-20,3*k[1],1000)
Prob = np.zeros(len(k2))
for i in range(len(k2)):
    params = (k[0], k2[i], k[2])
    Prob[i] = P_MSE(t, params, x1_data, x2_data, m, xi, vi)
plt.plot(k2,Prob, color="red")
plt.show()

# %%
N = 1000

k2 = 200*random()
K2 = np.zeros(N)
delta = 50
accN = 0

for i in range(N):
    k2_ = k2 + delta * (2*random()-1)
    p  = P_MSE(t, (k[0], k2,  k[2]), x1_data, x2_data, m, xi, vi)
    p_ = P_MSE(t, (k[0], k2_, k[2]), x1_data, x2_data, m, xi, vi)
    if(p_ >= p or random() < p_/p):
        k2 = k2_
        accN += 1
    K2[i] = k2
print("rate :", accN/N)
# Out:
# rate : 1.0

# %%
plt.figure(figsize=(12,5), dpi=200)
ax1 = plt.subplot2grid((1, 3), (0, 0), colspan=1)
ax2 = plt.subplot2grid((1, 3), (0, 1), colspan=2)

k2 = np.linspace(K2.min(),K2.max(),1000)
Prob = np.zeros(len(k2))
for i in range(len(k2)):
    params = (k[0], k2[i], k[2])
    Prob[i] = P_MSE(t, params, x1_data, x2_data, m, xi, vi)

max_index, _ = find_peaks(Prob)
counts, bins = np.histogram(K2, bins=int(N/20))

ax1.plot(Prob, k2, color="red",linewidth=1, zorder=25,
         label=r"Probability of $E_{\rm MSE}$")
for k2_localmax in k2[max_index]:
    ax1.hlines(y=k2_localmax, xmin=0, xmax=1,       color="black", alpha=0.2, zorder=1, linewidth=0.5)
    ax2.hlines(y=k2_localmax, xmin=0, xmax=K2.size, color="black", alpha=0.2, zorder=1, linewidth=0.5)

ax1.hist(bins[:-1], bins, color="lightblue",
         weights=counts/counts.max(), zorder=20,
         orientation='horizontal', alpha=0.9,
         label=r"Histogram of MCMC")

ax2.plot(K2,color="k", linewidth=0.5,
        label=r"$\left({\rm step}, k_2\right)$")

ax1.invert_xaxis()
ax2.set_yticks([])
ax2.set_xticks([])
ax2.set_xlim(0,K2.size)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.subplots_adjust(wspace=0)
plt.show()

# %%
k2 = np.linspace(-50.5, 3*k[1],3000)
MSEarr = np.zeros(len(k2))
for i in range(len(k2)):
    params = (k[0], k2[i], k[2])
    MSEarr[i] = MSE(t, params, x1_data, x2_data, m, xi, vi)

# %%
from scipy.signal import argrelmin,argrelmax
min_index = argrelmin(MSEarr)
max_index = argrelmax(MSEarr)
def printArr(arr):
    s = r"\left["
    for i in range(len(arr)):
        s += "%.8f,"%arr[i]
    s = s[:-1] + r"\right]"
    return s
    
    
MSEarrMax = MSEarr[max_index]
k2Max = k2[max_index]

MSEarrMin = MSEarr[min_index]
k2Min = k2[min_index]

print(r"\left(k_{max},E_{max}\right)")
print(r"\left(k_{min},E_{min}\right)")
print(r"E_{max} = ", printArr(MSEarrMax))
print(r"k_{max} = ", printArr(k2Max))
print(r"E_{min} = ", printArr(MSEarrMin))
print(r"k_{min} = ", printArr(k2Min))
# Out:
# \left(k_{max},E_{max}\right)
# \left(k_{min},E_{min}\right)
# E_{max} =  \left[0.02090343,0.02096967,0.02014253,0.02071236,0.01998165,0.02061340,0.02058016,0.02057719,0.02059643,0.02063634,0.02070251,0.02080619,0.02097475,0.02127590,0.02193626,0.02445157,0.02418382,0.02169004,0.02103284,0.02072960,0.02055564,0.02044321,0.02036482\right]
# k_{max} =  \left[-49.68189396,-48.98066022,-47.81193731,-46.52634211,-44.30576859,-42.43581194,-36.82594198,-29.69673224,-20.93131044,-10.64654885,1.27442481,14.71473825,29.79126375,46.38712904,64.73607869,84.83811270,116.04301434,140.46932311,166.06435478,193.29559853,221.92930977,252.31610537,284.10536846\right]
# E_{min} =  \left[0.01775771,0.01936281,0.01907168,0.01981743,0.01927930,0.01993608,0.01934999,0.01937315,0.01936996,0.01934464,0.01929612,0.01921624,0.01908805,0.01887020,0.01844560,0.01731380,0.00000028,0.01750896,0.01865751,0.01909210,0.01931972,0.01945919,0.01955300,0.01962018\right]
# k_{min} =  \left[-49.91563855,-49.44814938,-48.51317106,-47.34444815,-45.47449150,-43.83827943,-40.79959987,-34.48849617,-26.54118039,-17.07452484,-5.85478493,6.88429476,21.25958653,37.27109036,54.80193398,74.20273424,100.03151050,127.84711571,152.50716906,178.56968990,206.26842281,235.48649550,266.22390797,298.59753251\right]

# %%
fig.savefig("../MCMC-note/fig/MSE_peak.pdf" , pad_inches=0.0)

# %%
x = np.linspace(-50, 300, 3501)
y1 = 0.02 * (1 + np.exp(-(0.128373*np.abs(x-100))**0.496685))
y2 = 0.02 * (1 - np.exp(-(0.128373*np.abs(x-100))**0.496685))

fig = plt.figure(figsize=(10,3),dpi=100)
plt.plot(x, y1, color="red", label="fitting of local maximum")
plt.plot(x, y2, color="blue", label="fitting of local minimum")
plt.plot(k2,MSEarr, color="black")
plt.ylim(-0.01,0.05)
plt.xlabel(r"$k_2$")
plt.ylabel(r"$E_{\rm MSE}$")
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
x
# Out:
# array([-5.00000000e+01, -4.96496496e+01, -4.92992993e+01, -4.89489489e+01,
#        -4.85985986e+01, -4.82482482e+01, -4.78978979e+01, -4.75475475e+01,
#        -4.71971972e+01, -4.68468468e+01, -4.64964965e+01, -4.61461461e+01,
#        -4.57957958e+01, -4.54454454e+01, -4.50950951e+01, -4.47447447e+01,
#        -4.43943944e+01, -4.40440440e+01, -4.36936937e+01, -4.33433433e+01,
#        -4.29929930e+01, -4.26426426e+01, -4.22922923e+01, -4.19419419e+01,
#        -4.15915916e+01, -4.12412412e+01, -4.08908909e+01, -4.05405405e+01,
#        -4.01901902e+01, -3.98398398e+01, -3.94894895e+01, -3.91391391e+01,
#        -3.87887888e+01, -3.84384384e+01, -3.80880881e+01, -3.77377377e+01,
#        -3.73873874e+01, -3.70370370e+01, -3.66866867e+01, -3.63363363e+01,
#        -3.59859860e+01, -3.56356356e+01, -3.52852853e+01, -3.49349349e+01,
#        -3.45845846e+01, -3.42342342e+01, -3.38838839e+01, -3.35335335e+01,
#        -3.31831832e+01, -3.28328328e+01, -3.24824825e+01, -3.21321321e+01,
#        -3.17817818e+01, -3.14314314e+01, -3.10810811e+01, -3.07307307e+01,
#        -3.03803804e+01, -3.00300300e+01, -2.96796797e+01, -2.93293293e+01,
#        -2.89789790e+01, -2.86286286e+01, -2.82782783e+01, -2.79279279e+01,
#        -2.75775776e+01, -2.72272272e+01, -2.68768769e+01, -2.65265265e+01,
#        -2.61761762e+01, -2.58258258e+01, -2.54754755e+01, -2.51251251e+01,
#        -2.47747748e+01, -2.44244244e+01, -2.40740741e+01, -2.37237237e+01,
#        -2.33733734e+01, -2.30230230e+01, -2.26726727e+01, -2.23223223e+01,
#        -2.19719720e+01, -2.16216216e+01, -2.12712713e+01, -2.09209209e+01,
#        -2.05705706e+01, -2.02202202e+01, -1.98698699e+01, -1.95195195e+01,
